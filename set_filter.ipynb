# %%
import json

# %%
with open(r"C:\Users\dirac\software\orulings\scripts\riftbound_cards_with_errata.json", 'r', encoding='utf-8') as f:
    x = f.read()

# %%
data  = json.loads(x)

# %%
new_list = []
for entry in data:
    if entry["card_set"] == "Unleashed":
        new_list.append(entry)

# %%
len(new_list)
# Out:
# 286

# %%
len(data)
# Out:
# 950

# %%
out = json.dumps(new_list)
with open("unleashed_only.json", 'w') as f:
    f.write(out)
